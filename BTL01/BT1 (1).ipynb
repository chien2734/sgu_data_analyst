# %% [markdown]
# # BÀI TẬP THỰC HÀNH 1
# ## Thực hiện thống kê mô tả trên tập dữ liệu về phân loại chất lượng rượu đỏ
# Nguồn dữ liệu: [Red Wine Quality Dataset - Kaggle](https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification)

# %% [markdown]
# ### 1. Nhập thư viện
# **Mô tả:**
# Cell này nhập các thư viện cần thiết cho quá trình phân tích và trực quan hóa dữ liệu.

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# # 2. Đọc dữ liệu
# Đọc tập dữ liệu winequality-red.csv vào DataFrame df.

# %%
wine = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/EDA/winequality-red.csv", sep=",")

# %% [markdown]
# # 3. Thông tin tổng quan

# %%
# shape
print(f'+ Shape: {wine.shape}')
# types
print(f'+ Data Types: \n{wine.dtypes}')
# head, tail
print(f'+ Contents: ')
display(wine.head(5))
display(wine.tail(5))
# info
wine.info()
desc = wine.describe().T
# Out:
# + Shape: (1599, 12)
# + Data Types:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
# + Contents:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Các biến có quy mô giá trị khác nhau, ví dụ residual sugar và density dao động khác biệt. alcohol có giá trị trung bình khoảng 10.4%, điều này ảnh hưởng mạnh đến chất lượng rượu.

# %%
wine.loc[wine["alcohol"] < 0, "alcohol"] = np.median(wine["alcohol"])

# %% [markdown]
# # 5. Kiểm tra dữ liệu thiếu / giá trị bất hợp lý

# %%
print(wine.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Tập dữ liệu gồm 1359 dòng và 12 cột — mỗi dòng đại diện cho một mẫu rượu, các cột là các chỉ số hóa học hoặc chất lượng cảm quan. Không có dữ liệu bị thiếu, tuy nhiên có vài cột có giá trị 0 (như citric acid hoặc residual sugar), cần cân nhắc khi phân tích.

# %% [markdown]
# # 6. Bổ sung độ lệch và độ nhọn

# %%
from scipy.stats import skew, kurtosis
desc["skewness"] = wine.skew()
desc["kurtosis"] = wine.kurtosis()
print(desc)
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max  skewness   kurtosis
# fixed acidity          7.90000   9.200000   15.90000  0.982751   1.132143
# volatile acidity       0.52000   0.640000    1.58000  0.671593   1.225542
# citric acid            0.26000   0.420000    1.00000  0.318337  -0.788998
# residual sugar         2.20000   2.600000   15.50000  4.540655  28.617595
# chlorides              0.07900   0.090000    0.61100  5.680347  41.715787
# free sulfur dioxide   14.00000  21.000000   72.00000  1.250567   2.023562
# total sulfur dioxide  38.00000  62.000000  289.00000  1.515531   3.809824
# density                0.99675   0.997835    1.00369  0.071288   0.934079
# pH                     3.31000   3.400000    4.01000  0.193683   0.806943
# sulphates              0.62000   0.730000    2.00000  2.428672  11.720251
# alcohol               10.20000  11.100000   14.90000  0.860829   0.200029
# quality                6.00000   6.000000    8.00000  0.217802   0.296708

# %% [markdown]
# **Nhận xét**:
#
# Bổ sung độ lệch (skewness) và độ nhọn (kurtosis) giúp hiểu sâu hơn về hình dạng phân phối dữ liệu.
# Một số biến như residual sugar và chlorides có độ lệch dương lớn → phân phối lệch phải mạnh, chứa nhiều giá trị ngoại lai.
# Các biến có kurtosis cao (>3) cần được chuẩn hóa hoặc log-transform để giảm ảnh hưởng của outlier.

# %% [markdown]
# # 7. So sánh trung bình theo nhóm chất lượng

# %%
wine["quality_label"] = wine["quality"].apply(lambda q: "good" if q >= 6 else "bad")
print(wine["quality_label"].value_counts())
print(wine["quality_label"].value_counts(normalize=True))
# Out:
# quality_label
# good    855
# bad     744
# Name: count, dtype: int64
# quality_label
# good    0.534709
# bad     0.465291
# Name: proportion, dtype: float64

# %%
groups = wine.groupby("quality_label")
for name, group in groups:
    print(f"==== {name} ====")
    print(group.describe().T)
# Out:
# ==== bad ====
#                       count       mean        std      min       25%  \
# fixed acidity         744.0   8.142204   1.572396  4.60000   7.10000
# volatile acidity      744.0   0.589503   0.177956  0.18000   0.46000
# citric acid           744.0   0.237755   0.183368  0.00000   0.08000
# residual sugar        744.0   2.542070   1.393550  1.20000   1.90000
# chlorides             744.0   0.092989   0.055781  0.03900   0.07400
# free sulfur dioxide   744.0  16.567204  10.890291  3.00000   8.00000
# total sulfur dioxide  744.0  54.645161  36.720468  6.00000  23.75000
# density               744.0   0.997068   0.001598  0.99256   0.99612
# pH                    744.0   3.311653   0.154296  2.74000   3.20000
# sulphates             744.0   0.618535   0.176194  0.33000   0.52000
# alcohol               744.0   9.926478   0.758007  8.40000   9.40000
# quality               744.0   4.901882   0.339894  3.00000   5.00000
#
#                             50%      75%        max
# fixed acidity          7.800000   8.9000   15.90000
# volatile acidity       0.590000   0.6800    1.58000
# citric acid            0.220000   0.3600    1.00000
# residual sugar         2.200000   2.6000   15.50000
# chlorides              0.081000   0.0940    0.61100
# free sulfur dioxide   14.000000  23.0000   68.00000
# total sulfur dioxide  45.000000  78.0000  155.00000
# density                0.996935   0.9979    1.00315
# pH                     3.310000   3.4000    3.90000
# sulphates              0.580000   0.6500    2.00000
# alcohol                9.700000  10.3000   14.90000
# quality                5.000000   5.0000    5.00000
# ==== good ====
#                       count       mean        std      min        25%  \
# fixed acidity         855.0   8.474035   1.862795  4.70000   7.100000
# volatile acidity      855.0   0.474146   0.161999  0.12000   0.350000
# citric acid           855.0   0.299883   0.199889  0.00000   0.115000
# residual sugar        855.0   2.535965   1.424835  0.90000   1.900000
# chlorides             855.0   0.082661   0.037258  0.01200   0.067000
# free sulfur dioxide   855.0  15.272515  10.038538  1.00000   7.000000
# total sulfur dioxide  855.0  39.352047  27.253280  6.00000  20.000000
# density               855.0   0.996467   0.002067  0.99007   0.995185
# pH                    855.0   3.310643   0.154554  2.86000   3.210000
# sulphates             855.0   0.692620   0.155558  0.39000   0.590000
# alcohol               855.0  10.855029   1.106109  8.40000  10.000000
# quality               855.0   6.274854   0.491627  6.00000   6.000000
#
#                           50%        75%        max
# fixed acidity          8.0000   9.650000   15.60000
# volatile acidity       0.4600   0.580000    1.04000
# citric acid            0.3100   0.460000    0.78000
# residual sugar         2.2000   2.600000   15.40000
# chlorides              0.0770   0.087500    0.41500
# free sulfur dioxide   13.0000  20.500000   72.00000
# total sulfur dioxide  33.0000  50.000000  289.00000
# density                0.9964   0.997685    1.00369
# pH                     3.3100   3.400000    4.01000
# sulphates              0.6600   0.770000    1.95000
# alcohol               10.8000  11.700000   14.00000
# quality                6.0000   7.000000    8.00000

# %% [markdown]
# **Nhận xét:**
#
# Rượu “High” có alcohol cao hơn, volatile acidity thấp hơn rõ rệt so với nhóm “Low”. Đây là các yếu tố ảnh hưởng chính đến chất lượng cảm quan.

# %% [markdown]
# # 8. Thống kê mô tả chi tiết thủ công cho từng cột số (numeric column)

# %%
data = wine.select_dtypes(include=[np.number])

for col in data.columns:
    values = data[col].values

    mean = np.mean(values)
    median = np.median(values)
    mode = stats.mode(values, keepdims=True)   # mode trả về object
    var = np.var(values, ddof=1)               # sample variance (ddof=1)
    std = np.std(values, ddof=1)               # sample standard deviation
    data_range = np.max(values) - np.min(values)
    q1 = np.percentile(values, 25)
    q3 = np.percentile(values, 75)
    iqr = q3 - q1

    print(f"\n=== {col} ===")
    print(f"Mean: {mean:.4f}")
    print(f"Median: {median:.4f}")
    print(f"Mode: {mode.mode[0]} (Count={mode.count[0]})")
    print(f"Variance: {var:.4f}")
    print(f"Standard Deviation: {std:.4f}")
    print(f"Range: {data_range:.4f}")
    print(f"Q1 (25%): {q1:.4f}")
    print(f"Q3 (75%): {q3:.4f}")
    print(f"IQR: {iqr:.4f}")
# Out:
# === fixed acidity ===
# Mean: 8.3196
# Median: 7.9000
# Mode: 7.2 (Count=67)
# Variance: 3.0314
# Standard Deviation: 1.7411
# Range: 11.3000
# Q1 (25%): 7.1000
# Q3 (75%): 9.2000
# IQR: 2.1000
#
# === volatile acidity ===
# Mean: 0.5278
# Median: 0.5200
# Mode: 0.6 (Count=47)
# Variance: 0.0321
# Standard Deviation: 0.1791
# Range: 1.4600
# Q1 (25%): 0.3900
# Q3 (75%): 0.6400
# IQR: 0.2500
#
# === citric acid ===
# Mean: 0.2710
# Median: 0.2600
# Mode: 0.0 (Count=132)
# Variance: 0.0379
# Standard Deviation: 0.1948
# Range: 1.0000
# Q1 (25%): 0.0900
# Q3 (75%): 0.4200
# IQR: 0.3300
#
# === residual sugar ===
# Mean: 2.5388
# Median: 2.2000
# Mode: 2.0 (Count=156)
# Variance: 1.9879
# Standard Deviation: 1.4099
# Range: 14.6000
# Q1 (25%): 1.9000
# Q3 (75%): 2.6000
# IQR: 0.7000
#
# === chlorides ===
# Mean: 0.0875
# Median: 0.0790
# Mode: 0.08 (Count=66)
# Variance: 0.0022
# Standard Deviation: 0.0471
# Range: 0.5990
# Q1 (25%): 0.0700
# Q3 (75%): 0.0900
# IQR: 0.0200
#
# === free sulfur dioxide ===
# Mean: 15.8749
# Median: 14.0000
# Mode: 6.0 (Count=138)
# Variance: 109.4149
# Standard Deviation: 10.4602
# Range: 71.0000
# Q1 (25%): 7.0000
# Q3 (75%): 21.0000
# IQR: 14.0000
#
# === total sulfur dioxide ===
# Mean: 46.4678
# Median: 38.0000
# Mode: 28.0 (Count=43)
# Variance: 1082.1024
# Standard Deviation: 32.8953
# Range: 283.0000
# Q1 (25%): 22.0000
# Q3 (75%): 62.0000
# IQR: 40.0000
#
# === density ===
# Mean: 0.9967
# Median: 0.9968
# Mode: 0.9972 (Count=36)
# Variance: 0.0000
# Standard Deviation: 0.0019
# Range: 0.0136
# Q1 (25%): 0.9956
# Q3 (75%): 0.9978
# IQR: 0.0022
#
# === pH ===
# Mean: 3.3111
# Median: 3.3100
# Mode: 3.3 (Count=57)
# Variance: 0.0238
# Standard Deviation: 0.1544
# Range: 1.2700
# Q1 (25%): 3.2100
# Q3 (75%): 3.4000
# IQR: 0.1900
#
# === sulphates ===
# Mean: 0.6581
# Median: 0.6200
# Mode: 0.6 (Count=69)
# Variance: 0.0287
# Standard Deviation: 0.1695
# Range: 1.6700
# Q1 (25%): 0.5500
# Q3 (75%): 0.7300
# IQR: 0.1800
#
# === alcohol ===
# Mean: 10.4230
# Median: 10.2000
# Mode: 9.5 (Count=139)
# Variance: 1.1356
# Standard Deviation: 1.0657
# Range: 6.5000
# Q1 (25%): 9.5000
# Q3 (75%): 11.1000
# IQR: 1.6000
#
# === quality ===
# Mean: 5.6360
# Median: 6.0000
# Mode: 5 (Count=681)
# Variance: 0.6522
# Standard Deviation: 0.8076
# Range: 5.0000
# Q1 (25%): 5.0000
# Q3 (75%): 6.0000
# IQR: 1.0000

# %% [markdown]
# **Nhận xét**:
#
# Các biến có độ lệch cao như residual sugar, chlorides có phân bố không chuẩn.
#
# Các đặc trưng như alcohol có Mean > Median, cho thấy xu hướng lệch phải nhẹ.
#
# IQR nhỏ ở pH → dữ liệu tập trung quanh trung bình, ít biến động.
#
# Có thể chuẩn hóa hoặc log-transform một số biến để giảm ảnh hưởng outlier.
